# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
X = data.data
y = data.target
print(X.shape, y.shape)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
model_3 = Sequential()
model_3.add(Dense(units=16, input_dim= X.shape[1], activation='sigmoid'))
model_3.add(Dense(units=8, activation='sigmoid'))
model_3.add(Dense(units=1, activation='sigmoid'))
model_3.compile(optimizer='sgd', loss='binary_crossentropy',
metrics=['accuracy'])
history = model_3.fit(X_train, y_train, epochs=50, batch_size=32,
validation_data=(X_test, y_test))
loss, accuracy = model_3.evaluate(X_test, y_test)
print(f"Loss: {loss}, Accuracy: {accuracy}")
import matplotlib.pyplot as plt
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# WARNING:tensorflow:From c:\Users\MaoYeral\miniconda3\envs\ML_2\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# (569, 30) (569,)
# (398, 30) (171, 30) (398,) (171,)
# WARNING:tensorflow:From c:\Users\MaoYeral\miniconda3\envs\ML_2\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\MaoYeral\miniconda3\envs\ML_2\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\MaoYeral\miniconda3\envs\ML_2\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\MaoYeral\miniconda3\envs\ML_2\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 13/13 [==============================] - 1s 19ms/step - loss: 0.6521 - accuracy: 0.6432 - val_loss: 0.6797 - val_accuracy: 0.5906
# Epoch 2/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6518 - accuracy: 0.6432 - val_loss: 0.6801 - val_accuracy: 0.5906
# Epoch 3/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6516 - accuracy: 0.6432 - val_loss: 0.6801 - val_accuracy: 0.5906
# Epoch 4/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6514 - accuracy: 0.6432 - val_loss: 0.6799 - val_accuracy: 0.5906
# Epoch 5/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6507 - accuracy: 0.6432 - val_loss: 0.6792 - val_accuracy: 0.5906
# Epoch 6/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6493 - accuracy: 0.6432 - val_loss: 0.6781 - val_accuracy: 0.5906
# Epoch 7/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6480 - accuracy: 0.6432 - val_loss: 0.6766 - val_accuracy: 0.5906
# Epoch 8/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6463 - accuracy: 0.6432 - val_loss: 0.6757 - val_accuracy: 0.5906
# Epoch 9/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6455 - accuracy: 0.6432 - val_loss: 0.6747 - val_accuracy: 0.5906
# Epoch 10/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6449 - accuracy: 0.6432 - val_loss: 0.6742 - val_accuracy: 0.5906
# Epoch 11/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6444 - accuracy: 0.6432 - val_loss: 0.6733 - val_accuracy: 0.5906
# Epoch 12/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6439 - accuracy: 0.6432 - val_loss: 0.6731 - val_accuracy: 0.5906
# Epoch 13/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6433 - accuracy: 0.6432 - val_loss: 0.6718 - val_accuracy: 0.5906
# Epoch 14/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6429 - accuracy: 0.6432 - val_loss: 0.6710 - val_accuracy: 0.5906
# Epoch 15/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6423 - accuracy: 0.6432 - val_loss: 0.6713 - val_accuracy: 0.5906
# Epoch 16/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6423 - accuracy: 0.6432 - val_loss: 0.6704 - val_accuracy: 0.5906
# Epoch 17/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6411 - accuracy: 0.6432 - val_loss: 0.6693 - val_accuracy: 0.5906
# Epoch 18/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6409 - accuracy: 0.6432 - val_loss: 0.6692 - val_accuracy: 0.5906
# Epoch 19/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6402 - accuracy: 0.6432 - val_loss: 0.6696 - val_accuracy: 0.5906
# Epoch 20/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6400 - accuracy: 0.6432 - val_loss: 0.6696 - val_accuracy: 0.5906
# Epoch 21/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6390 - accuracy: 0.6432 - val_loss: 0.6685 - val_accuracy: 0.5906
# Epoch 22/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6380 - accuracy: 0.6432 - val_loss: 0.6693 - val_accuracy: 0.5906
# Epoch 23/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6378 - accuracy: 0.6432 - val_loss: 0.6668 - val_accuracy: 0.5906
# Epoch 24/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6372 - accuracy: 0.6432 - val_loss: 0.6674 - val_accuracy: 0.5906
# Epoch 25/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6370 - accuracy: 0.6432 - val_loss: 0.6653 - val_accuracy: 0.5906
# Epoch 26/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6357 - accuracy: 0.6432 - val_loss: 0.6652 - val_accuracy: 0.5906
# Epoch 27/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6357 - accuracy: 0.6432 - val_loss: 0.6650 - val_accuracy: 0.5906
# Epoch 28/50
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6364 - accuracy: 0.6432 - val_loss: 0.6645 - val_accuracy: 0.5906
# Epoch 29/50
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6341 - accuracy: 0.6432 - val_loss: 0.6624 - val_accuracy: 0.5906
# Epoch 30/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6339 - accuracy: 0.6432 - val_loss: 0.6642 - val_accuracy: 0.5906
# Epoch 31/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6326 - accuracy: 0.6432 - val_loss: 0.6614 - val_accuracy: 0.5906
# Epoch 32/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6338 - accuracy: 0.6432 - val_loss: 0.6605 - val_accuracy: 0.5906
# Epoch 33/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6315 - accuracy: 0.6432 - val_loss: 0.6617 - val_accuracy: 0.5906
# Epoch 34/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6316 - accuracy: 0.6432 - val_loss: 0.6607 - val_accuracy: 0.5906
# Epoch 35/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6298 - accuracy: 0.6432 - val_loss: 0.6584 - val_accuracy: 0.5906
# Epoch 36/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6299 - accuracy: 0.6432 - val_loss: 0.6599 - val_accuracy: 0.5906
# Epoch 37/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6287 - accuracy: 0.6432 - val_loss: 0.6596 - val_accuracy: 0.5906
# Epoch 38/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6288 - accuracy: 0.6432 - val_loss: 0.6571 - val_accuracy: 0.5906
# Epoch 39/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6284 - accuracy: 0.6432 - val_loss: 0.6580 - val_accuracy: 0.5906
# Epoch 40/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6276 - accuracy: 0.6432 - val_loss: 0.6585 - val_accuracy: 0.5906
# Epoch 41/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6264 - accuracy: 0.6432 - val_loss: 0.6567 - val_accuracy: 0.5906
# Epoch 42/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6261 - accuracy: 0.6432 - val_loss: 0.6547 - val_accuracy: 0.5906
# Epoch 43/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6244 - accuracy: 0.6432 - val_loss: 0.6547 - val_accuracy: 0.5906
# Epoch 44/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6251 - accuracy: 0.6432 - val_loss: 0.6561 - val_accuracy: 0.5906
# Epoch 45/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6232 - accuracy: 0.6432 - val_loss: 0.6552 - val_accuracy: 0.5906
# Epoch 46/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6245 - accuracy: 0.6432 - val_loss: 0.6507 - val_accuracy: 0.5906
# Epoch 47/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6220 - accuracy: 0.6432 - val_loss: 0.6542 - val_accuracy: 0.5906
# Epoch 48/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6222 - accuracy: 0.6432 - val_loss: 0.6508 - val_accuracy: 0.5906
# Epoch 49/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6205 - accuracy: 0.6432 - val_loss: 0.6504 - val_accuracy: 0.5906
# Epoch 50/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6207 - accuracy: 0.6432 - val_loss: 0.6558 - val_accuracy: 0.5906
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6558 - accuracy: 0.5906
# Loss: 0.6557908058166504, Accuracy: 0.5906432867050171
