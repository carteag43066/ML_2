# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_breast_cancer

#1. The libraries keras.models and keras.layers are imported to design a
#sequential model having dense layers. We need to import the train_test_
#split from sklearn.model_selection module for splitting the data into train
#and test sets.

data = load_breast_cancer()
X = data.data
y = data.target
print(X.shape, y.shape)

#2. The breast cancer dataset is loaded using the load_breast_cancer function.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

#3. The train_test_split function is used to split the dataset into train
#and test sets.

model_3 = Sequential()
model_3.add(Dense(units=16, input_dim= X.shape[1], activation='sigmoid'))
model_3.add(Dense(units=8, activation='sigmoid'))
model_3.add(Dense(units=1, activation='sigmoid'))

#4. The model having an input layer with two dense layers of 16 and 8
#(hidden layer) neurons followed by a dense layer of 1 (for output) neuron
#with sigmoid activation is created. The model is compiled with 'sgd'
#optimizer, binary cross entropy loss (binary classification), and accuracy
#metric. The model is trained over 50 epochs with the training set.

model_3.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
history = model_3.fit(X_train, y_train, epochs=50, batch_size=32,
                      validation_data=(X_test, y_test))
loss, accuracy = model_3.evaluate(X_test, y_test)
print(f"Loss: {loss}, Accuracy: {accuracy}")

#5. Note that after compiling the model, the output was saved in a variable
#called history. This is a dictionary from which training and validation
#accuracy and loss are plotted.

import matplotlib.pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# (569, 30) (569,)
# (398, 30) (171, 30) (398,) (171,)
# Epoch 1/50
# 13/13 [==============================] - 0s 10ms/step - loss: 0.7003 - accuracy: 0.6281 - val_loss: 0.6968 - val_accuracy: 0.6257
# Epoch 2/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6909 - accuracy: 0.6281 - val_loss: 0.6890 - val_accuracy: 0.6257
# Epoch 3/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.6281 - val_loss: 0.6794 - val_accuracy: 0.6257
# Epoch 4/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6753 - accuracy: 0.6281 - val_loss: 0.6739 - val_accuracy: 0.6257
# Epoch 5/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6689 - accuracy: 0.6281 - val_loss: 0.6682 - val_accuracy: 0.6257
# Epoch 6/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6645 - accuracy: 0.6281 - val_loss: 0.6627 - val_accuracy: 0.6257
# Epoch 7/50
# ...

# %% [markdown]
# ## Variacion 1

# %%
from keras.optimizers import Adam

model_3_v1 = Sequential()
model_3_v1.add(Dense(units=16, input_dim= X.shape[1], activation='sigmoid'))
model_3_v1.add(Dense(units=8, activation='sigmoid'))
model_3_v1.add(Dense(units=1, activation='sigmoid'))

#4. The model having an input layer with two dense layers of 16 and 8
#(hidden layer) neurons followed by a dense layer of 1 (for output) neuron
#with sigmoid activation is created. The model is compiled with 'sgd'
#optimizer, binary cross entropy loss (binary classification), and accuracy
#metric. The model is trained over 50 epochs with the training set.

model_3_v1.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
history = model_3_v1.fit(X_train, y_train, epochs=50, batch_size=32,
                      validation_data=(X_test, y_test))
loss, accuracy = model_3_v1.evaluate(X_test, y_test)
print(f"Loss: {loss}, Accuracy: {accuracy}")

#5. Note that after compiling the model, the output was saved in a variable
#called history. This is a dictionary from which training and validation
#accuracy and loss are plotted.

import matplotlib.pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6510 - accuracy: 0.6281 - val_loss: 0.6432 - val_accuracy: 0.6257
# Epoch 2/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6399 - accuracy: 0.6281 - val_loss: 0.6251 - val_accuracy: 0.6257
# Epoch 3/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6156 - accuracy: 0.6281 - val_loss: 0.6014 - val_accuracy: 0.6257
# Epoch 4/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5987 - accuracy: 0.6281 - val_loss: 0.5852 - val_accuracy: 0.6257
# Epoch 5/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5873 - accuracy: 0.6281 - val_loss: 0.5737 - val_accuracy: 0.6257
# Epoch 6/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5759 - accuracy: 0.6281 - val_loss: 0.5611 - val_accuracy: 0.6257
# Epoch 7/50
# ...

# %% [markdown]
# ## Variacion 2

# %%
model_3_v2 = Sequential()
model_3_v2.add(Dense(units=16, input_dim= X.shape[1], activation='sigmoid'))
model_3_v2.add(Dense(units=8, activation='sigmoid'))
model_3_v2.add(Dense(units=1, activation='sigmoid'))

#4. The model having an input layer with two dense layers of 16 and 8
#(hidden layer) neurons followed by a dense layer of 1 (for output) neuron
#with sigmoid activation is created. The model is compiled with 'sgd'
#optimizer, binary cross entropy loss (binary classification), and accuracy
#metric. The model is trained over 50 epochs with the training set.

model_3_v2.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
history = model_3_v2.fit(X_train, y_train, epochs=100, batch_size=32,
                      validation_data=(X_test, y_test))
loss, accuracy = model_3_v2.evaluate(X_test, y_test)
print(f"Loss: {loss}, Accuracy: {accuracy}")

#5. Note that after compiling the model, the output was saved in a variable
#called history. This is a dictionary from which training and validation
#accuracy and loss are plotted.

import matplotlib.pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6681 - accuracy: 0.6281 - val_loss: 0.6666 - val_accuracy: 0.6257
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6541 - accuracy: 0.6281 - val_loss: 0.6566 - val_accuracy: 0.6257
# Epoch 3/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6478 - accuracy: 0.6281 - val_loss: 0.6485 - val_accuracy: 0.6257
# Epoch 4/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6407 - accuracy: 0.6281 - val_loss: 0.6399 - val_accuracy: 0.6257
# Epoch 5/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6330 - accuracy: 0.6281 - val_loss: 0.6356 - val_accuracy: 0.6257
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6280 - accuracy: 0.6281 - val_loss: 0.6329 - val_accuracy: 0.6257
# Epoch 7/100
# ...

# %% [markdown]
# ## Variacion 3

# %%
model_3_v3 = Sequential()
model_3_v3.add(Dense(units=16, input_dim= X.shape[1], activation='relu'))
model_3_v3.add(Dense(units=8, activation='relu'))
model_3_v3.add(Dense(units=1, activation='sigmoid'))

#4. The model having an input layer with two dense layers of 16 and 8
#(hidden layer) neurons followed by a dense layer of 1 (for output) neuron
#with sigmoid activation is created. The model is compiled with 'sgd'
#optimizer, binary cross entropy loss (binary classification), and accuracy
#metric. The model is trained over 50 epochs with the training set.

model_3_v3.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
history = model_3_v3.fit(X_train, y_train, epochs=200, batch_size=32,
                      validation_data=(X_test, y_test))
loss, accuracy = model_3_v3.evaluate(X_test, y_test)
print(f"Loss: {loss}, Accuracy: {accuracy}")

#5. Note that after compiling the model, the output was saved in a variable
#called history. This is a dictionary from which training and validation
#accuracy and loss are plotted.

import matplotlib.pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/200
# 13/13 [==============================] - 0s 9ms/step - loss: 56.7950 - accuracy: 0.3719 - val_loss: 24.8284 - val_accuracy: 0.3684
# Epoch 2/200
# 13/13 [==============================] - 0s 3ms/step - loss: 9.3254 - accuracy: 0.6131 - val_loss: 5.7843 - val_accuracy: 0.8070
# Epoch 3/200
# 13/13 [==============================] - 0s 3ms/step - loss: 5.2322 - accuracy: 0.8241 - val_loss: 1.7981 - val_accuracy: 0.8713
# Epoch 4/200
# 13/13 [==============================] - 0s 2ms/step - loss: 2.5259 - accuracy: 0.7663 - val_loss: 2.0212 - val_accuracy: 0.7836
# Epoch 5/200
# 13/13 [==============================] - 0s 3ms/step - loss: 2.2043 - accuracy: 0.8492 - val_loss: 1.6974 - val_accuracy: 0.8947
# Epoch 6/200
# 13/13 [==============================] - 0s 3ms/step - loss: 1.9611 - accuracy: 0.8216 - val_loss: 1.8942 - val_accuracy: 0.8012
# Epoch 7/200
# ...

# %% [markdown]
# ## Variacion 4

# %%
model_3_v4 = Sequential()
model_3_v4.add(Dense(units=25, input_dim= X.shape[1], activation='sigmoid'))
model_3_v4.add(Dense(units=12, activation='sigmoid'))
model_3_v4.add(Dense(units=1, activation='sigmoid'))

#4. The model having an input layer with two dense layers of 16 and 8
#(hidden layer) neurons followed by a dense layer of 1 (for output) neuron
#with sigmoid activation is created. The model is compiled with 'sgd'
#optimizer, binary cross entropy loss (binary classification), and accuracy
#metric. The model is trained over 50 epochs with the training set.

model_3_v4.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
history = model_3_v4.fit(X_train, y_train, epochs=50, batch_size=32,
                      validation_data=(X_test, y_test))
loss, accuracy = model_3_v4.evaluate(X_test, y_test)
print(f"Loss: {loss}, Accuracy: {accuracy}")

#5. Note that after compiling the model, the output was saved in a variable
#called history. This is a dictionary from which training and validation
#accuracy and loss are plotted.

import matplotlib.pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6612 - accuracy: 0.6281 - val_loss: 0.6622 - val_accuracy: 0.6257
# Epoch 2/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6602 - accuracy: 0.6281 - val_loss: 0.6614 - val_accuracy: 0.6257
# Epoch 3/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6598 - accuracy: 0.6281 - val_loss: 0.6613 - val_accuracy: 0.6257
# Epoch 4/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6603 - accuracy: 0.6281 - val_loss: 0.6611 - val_accuracy: 0.6257
# Epoch 5/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6595 - accuracy: 0.6281 - val_loss: 0.6601 - val_accuracy: 0.6257
# Epoch 6/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6579 - accuracy: 0.6281 - val_loss: 0.6582 - val_accuracy: 0.6257
# Epoch 7/50
# ...

# %% [markdown]
# ## Variacion 5

# %%
model_3_v5 = Sequential()
model_3_v5.add(Dense(units=50, input_dim= X.shape[1], activation='sigmoid'))
model_3_v5.add(Dense(units=25, activation='sigmoid'))
model_3_v5.add(Dense(units=1, activation='sigmoid'))

#4. The model having an input layer with two dense layers of 16 and 8
#(hidden layer) neurons followed by a dense layer of 1 (for output) neuron
#with sigmoid activation is created. The model is compiled with 'sgd'
#optimizer, binary cross entropy loss (binary classification), and accuracy
#metric. The model is trained over 50 epochs with the training set.

model_3_v5.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
history = model_3_v5.fit(X_train, y_train, epochs=100, batch_size=32,
                      validation_data=(X_test, y_test))
loss, accuracy = model_3_v5.evaluate(X_test, y_test)
print(f"Loss: {loss}, Accuracy: {accuracy}")

#5. Note that after compiling the model, the output was saved in a variable
#called history. This is a dictionary from which training and validation
#accuracy and loss are plotted.

import matplotlib.pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.7288 - accuracy: 0.6281 - val_loss: 0.7117 - val_accuracy: 0.6257
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6978 - accuracy: 0.6281 - val_loss: 0.6902 - val_accuracy: 0.6257
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6818 - accuracy: 0.6281 - val_loss: 0.6784 - val_accuracy: 0.6257
# Epoch 4/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6725 - accuracy: 0.6281 - val_loss: 0.6703 - val_accuracy: 0.6257
# Epoch 5/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6666 - accuracy: 0.6281 - val_loss: 0.6661 - val_accuracy: 0.6257
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6636 - accuracy: 0.6281 - val_loss: 0.6642 - val_accuracy: 0.6257
# Epoch 7/100
# ...

# %% [markdown]
# ## Variacion 6

# %%
model_3_v6 = Sequential()
model_3_v6.add(Dense(units=50, input_dim= X.shape[1], activation='relu'))
model_3_v6.add(Dense(units=25, activation='relu'))
model_3_v6.add(Dense(units=1, activation='sigmoid'))

#4. The model having an input layer with two dense layers of 16 and 8
#(hidden layer) neurons followed by a dense layer of 1 (for output) neuron
#with sigmoid activation is created. The model is compiled with 'sgd'
#optimizer, binary cross entropy loss (binary classification), and accuracy
#metric. The model is trained over 50 epochs with the training set.

model_3_v6.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
history = model_3_v6.fit(X_train, y_train, epochs=100, batch_size=32,
                      validation_data=(X_test, y_test))
loss, accuracy = model_3_v6.evaluate(X_test, y_test)
print(f"Loss: {loss}, Accuracy: {accuracy}")

#5. Note that after compiling the model, the output was saved in a variable
#called history. This is a dictionary from which training and validation
#accuracy and loss are plotted.

import matplotlib.pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 9ms/step - loss: 9263.7227 - accuracy: 0.5477 - val_loss: 0.6882 - val_accuracy: 0.6316
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6884 - accuracy: 0.6307 - val_loss: 0.6861 - val_accuracy: 0.6316
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6864 - accuracy: 0.6307 - val_loss: 0.6842 - val_accuracy: 0.6316
# Epoch 4/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6846 - accuracy: 0.6307 - val_loss: 0.6825 - val_accuracy: 0.6316
# Epoch 5/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6829 - accuracy: 0.6307 - val_loss: 0.6808 - val_accuracy: 0.6316
# Epoch 6/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6813 - accuracy: 0.6307 - val_loss: 0.6792 - val_accuracy: 0.6316
# Epoch 7/100
# ...

# %% [markdown]
# ### Variacion 7

# %%
model_3_v7 = Sequential()
model_3_v7.add(Dense(units=50, input_dim= X.shape[1], activation='relu'))
model_3_v7.add(Dense(units=25, activation='relu'))
model_3_v7.add(Dense(units=1, activation='sigmoid'))

#4. The model having an input layer with two dense layers of 16 and 8
#(hidden layer) neurons followed by a dense layer of 1 (for output) neuron
#with sigmoid activation is created. The model is compiled with 'sgd'
#optimizer, binary cross entropy loss (binary classification), and accuracy
#metric. The model is trained over 50 epochs with the training set.

model_3_v7.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
history = model_3_v7.fit(X_train, y_train, epochs=100, batch_size=32,
                      validation_data=(X_test, y_test))
loss, accuracy = model_3_v7.evaluate(X_test, y_test)
print(f"Loss: {loss}, Accuracy: {accuracy}")

#5. Note that after compiling the model, the output was saved in a variable
#called history. This is a dictionary from which training and validation
#accuracy and loss are plotted.

import matplotlib.pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 9ms/step - loss: 18.2922 - accuracy: 0.3920 - val_loss: 9.5917 - val_accuracy: 0.3275
# Epoch 2/100
# 13/13 [==============================] - 0s 3ms/step - loss: 3.9365 - accuracy: 0.4673 - val_loss: 1.5243 - val_accuracy: 0.4269
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5313 - accuracy: 0.8065 - val_loss: 0.4228 - val_accuracy: 0.8480
# Epoch 4/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2495 - accuracy: 0.9121 - val_loss: 0.2609 - val_accuracy: 0.8889
# Epoch 5/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2223 - accuracy: 0.9171 - val_loss: 0.2603 - val_accuracy: 0.8947
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2331 - accuracy: 0.9045 - val_loss: 0.2610 - val_accuracy: 0.9006
# Epoch 7/100
# ...
